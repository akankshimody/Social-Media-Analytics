# %%
import pandas as pd

# %%
df = pd.read_csv("chemtrails_centrality_metrics.csv")

# %%
df.head()
# Out:
#       Unnamed: 0  Betweenness    Degree  Closeness  In Degree  Out Degree
# 0  ShowMeTheSky1     0.000012  0.028795   0.000488   0.000976    0.027818
# 1   Flat67823361     0.000000  0.001952   0.006561   0.001952    0.000000
# 2         Cagsil     0.000000  0.004880   0.000000   0.000488    0.004392
# 3        BusyDrT     0.000000  0.001464   0.000000   0.000488    0.000976
# 4  WeihlJennifer     0.000000  0.000488   0.000488   0.000488    0.000000

# %%
len(df)
# Out:
# 2050

# %%
df[df["Betweenness"] == max(df["Betweenness"])]
# Out:
#       Unnamed: 0  Betweenness    Degree  Closeness  In Degree  Out Degree
# 175  thinkfree55     0.001518  0.313812   0.003471   0.003904    0.309907

# %% [markdown]
# Highest betweenness score goes to lucky winner thinkfree55 <br/>
# Other high quality interests of his include "zombie gate"(something decrying the dangers of 3G, 4G, 5G and Smombies(???)). This impressive individual is also trying to link coronavirus with chemtrails, so good for him I guess. <br/>
# Notable his relatively low In Degree compared to his higher Out Degree; implies that he is quoted more than he quotes.

# %%
df[df["Degree"] == max(df["Degree"])]
# Out:
#       Unnamed: 0  Betweenness    Degree  Closeness  In Degree  Out Degree
# 175  thinkfree55     0.001518  0.313812   0.003471   0.003904    0.309907

# %% [markdown]
# thinkfree55 is also the highest Degree person. Wow! Lucky Boy! <br/>
# implies he is the most popular <br/>

# %%
df[df["Closeness"] == max(df["Closeness"])]
# Out:
#         Unnamed: 0  Betweenness    Degree  Closeness  In Degree  Out Degree
# 700  TexasFlower65          0.0  0.024402   0.020501   0.024402         0.0

# %% [markdown]
# Out degree of 0 AND a Betweenness of 0!! What a fine lady <br/>
# But she also has a very high closeness score <br/>
# Also retweets from winner winner chicken dinners such as the one and only Donald J Trump <br/>
# Christian Extremist <br/>
# Outdegree of 0 and Betweenness of 0 --> indicates that she is not a bridge at all, and that she doesn't retweet as a part of this network <br/>
# So how did she get the highest closeness score? <br/>
# She only appears 4 times, and she is retweeted by thinkfree55, who has the highest Betweenness and Degree scores. <br/>
# the fact that she has the highest closeness implies that network isn't very tightknit/ that it's a lot of one-off people tweeting from the same person (perhaps thinkfree65)

# %%
tweets = pd.read_csv("tweets_chemtrails - tweets_chemtrails.csv")

# %%
df[df["In Degree"] == max(df["In Degree"])]
# Out:
#         Unnamed: 0  Betweenness    Degree  Closeness  In Degree  Out Degree
# 700  TexasFlower65          0.0  0.024402   0.020501   0.024402         0.0

# %% [markdown]
# TexasFlower also has the highest In Degree, meaning that she is one of the most retweeted person as a part of this network, which once again indicates that this isn't a very tight-knit community of people, seeing as how she's only been retweeted 4 times.

# %%
df[df["Out Degree"] == max(df["Out Degree"])]
# Out:
#       Unnamed: 0  Betweenness    Degree  Closeness  In Degree  Out Degree
# 175  thinkfree55     0.001518  0.313812   0.003471   0.003904    0.309907

# %% [markdown]
# ah yes thinkfree55, my old friend <br/>
# they have the highest Out-Degree score <br/>
# meaning that they are the biggest retweeter in this network <br/>
# and that he is the true afficianado in the world of chemtrail theorists

# %% [markdown]
# Final thoughts: not a very tight-knit network
